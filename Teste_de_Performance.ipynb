# %% [markdown]
# <a href="https://colab.research.google.com/github/matheuspretooo/AW1-2023/blob/main/Teste_de_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Questão 1

# A programação é o pilar dos computadores, sem a programação o computador é somente apenas um monte de hardware sem funcionalidade, tudo é scriptdado e funciona de forma harmoniosa por causa de programção

# %%
# Questão 2

print("Olá Mundo! Bem-vindo ao Cinema Digital")
# Out:
# Olá Mundo! Bem-vindo ao Cinema Digital

# %%
# Questão 3

disciplina = "Python"
turma = 101

print (disciplina)
print (turma)
# Out:
# Python
# 101

# %%
# Questão 4

peso_unidade = 80
quantidade = 10

peso_total = peso_unidade * quantidade

print (f"O peso total do estoque é: {peso_total}kg")
# Out:
# O peso total do estoque é: 800kg

# %%
# Questão 5

quantidade_maca = 150
preco_maca = 5.99

print(f"Quantidade: {quantidade_maca} unidades\nPreço: R${preco_maca}")
# Out:
# Quantidade: 150 unidades
# Preço: R$5.99

# %%
# Questão 6

contratos = 12
faturamento = 2500.50

print (f"{type(contratos)}\n{type(faturamento)}")
# Out:
# <class 'int'>
# <class 'float'>

# %%
# Questão 7

sensor_ativo = True

print (sensor_ativo)

sensor_ativo = False

print (sensor_ativo)
# Out:
# True
# False

# %%
# Questão 8

venda_smartphones = 5400
venda_acessorios = 1250.50
receita_total = venda_acessorios + venda_smartphones

print (receita_total)
# Out:
# 6650.5

# %%
# Questão 9

saldo_atual = 10000
valor_fatura = 3500
saldo_final = saldo_atual - valor_fatura

print (saldo_final)
# Out:
# 6500

# %%
# Questão 10

preco_fardo = 24
unidades = 6

preco_unitario = preco_fardo / unidades

print (preco_unitario)
# Out:
# 4.0

# %%
# Questão 11

capacidade = 550
unitario = 65
max = capacidade // unitario
print (f"Capacidade real: {max}")
porcentagem_max = ((max * unitario) / capacidade) * 100
print (f"Porcentagem máxima: {porcentagem_max:.2f}%")
# Out:
# Capacidade real: 8
# Porcentagem máxima: 94.55%

# %%
# Questão 12

total = 125
ciclo = 8
fase = total % ciclo
parada = (total - fase) + ciclo

print (f"Fase atual do ciclo: {fase}")
print (f"Próxima parada: {parada}")
# Out:
# Fase atual do ciclo: 5
# Próxima parada: 128

# %%
# Questão 13

custo_base = 2500
aliquota = 0.05
suporte = 150

valor_final = custo_base + (custo_base * aliquota) + suporte
print (valor_final)
# Out:
# 2775.0

# %%
# Questão 14

registro = 345
hr = round(registro / 60, 2)
print (hr)
# Out:
# 5.75

# %%
# Questão 15

voo1 = 3.77
voo2 = 214
voo_total = (((voo1 * 60) + voo2) * 60 )
energia = round(voo_total * 2.7, 2)

print (f"Total gasto de energia: {energia:.2f} joules")

emergencia = round(energia * 0.15, 2)

print (f"Margem de emergência: {emergencia:.2f} joules")
# Out:
# Total gasto de energia: 71312.40 joules
# Margem de emergência: 10696.86 joules

# %%
# Questão 16

total = 1527
horas = total // 60
minutos = total % 60
hora_pago = horas * 60
min_pago =  minutos * 1.2

print (f"Horas trabalhadas: {horas} horas")
print (f"Minutos excedentes: {minutos} minutos")
print (f"Valor pago pelas horas: R${hora_pago:.2f}")
print (f"Valor pago pelos minutos: R${min_pago:.2f}")
print (f"Valor total pago: R${hora_pago + min_pago:.2f}")
# Out:
# Horas trabalhadas: 25 horas
# Minutos excedentes: 27 minutos
# Valor pago pelas horas: R$1500.00
# Valor pago pelos minutos: R$32.40
# Valor total pago: R$1532.40
